# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("placement._Data.csv")

# %%
df.head(3)
# Out:
#    cgpa   iq  placement
# 0   6.8  123          1
# 1   5.9  106          0
# 2   5.3  121          0

# %%
#check if data is can be linearly separated

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x="cgpa", y="iq", data=df, hue="placement")
plt.show()

# %%
x=df.iloc[:,:-1]
y=df["placement"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 85.0

# %%
lr.predict([[6.8,123]])
# Out:
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in /Applications/anaconda3/lib/python3.12/site-packages (0.23.1)
# Requirement already satisfied: scipy>=1.2.1 in /Applications/anaconda3/lib/python3.12/site-packages (from mlxtend) (1.13.1)
# Requirement already satisfied: numpy>=1.16.2 in /Applications/anaconda3/lib/python3.12/site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in /Applications/anaconda3/lib/python3.12/site-packages (from mlxtend) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.0.2 in /Applications/anaconda3/lib/python3.12/site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /Applications/anaconda3/lib/python3.12/site-packages (from mlxtend) (3.8.4)
# Requirement already satisfied: joblib>=0.13.2 in /Applications/anaconda3/lib/python3.12/site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Applications/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Applications/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Applications/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Applications/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Applications/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (23.2)
# Requirement already satisfied: pillow>=8 in /Applications/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Applications/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Applications/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Applications/anaconda3/lib/python3.12/site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Applications/anaconda3/lib/python3.12/site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Applications/anaconda3/lib/python3.12/site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in /Applications/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=lr)
plt.show()
# Out:
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
